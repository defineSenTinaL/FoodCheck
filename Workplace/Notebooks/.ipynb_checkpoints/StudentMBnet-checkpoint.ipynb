# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import os
 
from shutil import copy

from tensorflow.keras.utils import get_file
from tensorflow.keras.applications import EfficientNetB4
from tensorflow.keras.callbacks import EarlyStopping , ModelCheckpoint

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten , Dense

# %% [markdown]
# # Downloading the Dataset

# %%
def get_data_extract():
  if "food-101" in os.listdir():
    print("Dataset already exists")
  else:
    tf.keras.utils.get_file(
    'food-101.tar.gz',
    'http://data.vision.ee.ethz.ch/cvl/food-101.tar.gz',
    cache_subdir='/content',
    extract=True,
    archive_format='tar',
    cache_dir=None
    )
    print("Dataset downloaded and extracted!")

# %%
# Download data and extract it to folder
get_data_extract()
# Out:
# Downloading data from http://data.vision.ee.ethz.ch/cvl/food-101.tar.gz
# 4996284416/4996278331 [==============================] - 350s 0us/step
# 4996292608/4996278331 [==============================] - 350s 0us/step
# Dataset downloaded and extracted!

# %%
os.listdir("food-101")
# Out:
# ['images', 'license_agreement.txt', 'README.txt', 'meta']

# %%
os.listdir("food-101/meta")
# Out:
# ['test.json',
#  'labels.txt',
#  'test.txt',
#  'train.json',
#  'classes.txt',
#  'train.txt']

# %%
print(f"The No of Classes in Dataset are : {len(os.listdir('/content/food-101/images'))}")
# Out:
# The No of Classes in Dataset are : 101

# %%
count = 0
for folder in os.listdir("food-101/images"):
  folder_path = os.path.join("food-101/images" , folder)
  print(f"The No of Images of Class : {folder} in Dataset are : {len(os.listdir(folder_path))}")
  count = count + 1000
# Out:
# The No of Images of Class : frozen_yogurt in Dataset are : 1000
# The No of Images of Class : cheesecake in Dataset are : 1000
# The No of Images of Class : risotto in Dataset are : 1000
# The No of Images of Class : donuts in Dataset are : 1000
# The No of Images of Class : sashimi in Dataset are : 1000
# The No of Images of Class : spring_rolls in Dataset are : 1000
# The No of Images of Class : panna_cotta in Dataset are : 1000
# The No of Images of Class : ravioli in Dataset are : 1000
# The No of Images of Class : apple_pie in Dataset are : 1000
# The No of Images of Class : pork_chop in Dataset are : 1000
# The No of Images of Class : club_sandwich in Dataset are : 1000
# The No of Images of Class : peking_duck in Dataset are : 1000
# The No of Images of Class : gnocchi in Dataset are : 1000
# The No of Images of Class : fried_rice in Dataset are : 1000
# The No of Images of Class : chicken_wings in Dataset are : 1000
# The No of Images of Class : hot_and_sour_soup in Dataset are : 1000
# The No of Images of Class : edamame in Dataset are : 1000
# The No of Images of Class : samosa in Dataset are : 1000
# The No of Images of Class : ceviche in Dataset are : 1000
# The No of Images of Class : miso_soup in Dataset are : 1000
# The No of Images of Class : cheese_plate in Dataset are : 1000
# The No of Images of Class : caesar_salad in Dataset are : 1000
# The No of Images of Class : cup_cakes in Dataset are : 1000
# The No of Images of Class : baby_back_ribs in Dataset are : 1000
# The No of Images of Class : mussels in Dataset are : 1000
# The No of Images of Class : bruschetta in Dataset are : 1000
# The No of Images of Class : chicken_quesadilla in Dataset are : 1000
# The No of Images of Class : falafel in Dataset are : 1000
# The No of Images of Class : macaroni_and_cheese in Dataset are : 1000
# The No of Images of Class : poutine in Dataset are : 1000
# The No of Images of Class : spaghetti_bolognese in Dataset are : 1000
# The No of Images of Class : gyoza in Dataset are : 1000
# The No of Images of Class : paella in Dataset are : 1000
# The No of Images of Class : oysters in Dataset are : 1000
# The No of Images of Class : pizza in Dataset are : 1000
# The No of Images of Class : french_toast in Dataset are : 1000
# The No of Images of Class : chocolate_mousse in Dataset are : 1000
# The No of Images of Class : lobster_bisque in Dataset are : 1000
# The No of Images of Class : escargots in Dataset are : 1000
# The No of Images of Class : seaweed_salad in Dataset are : 1000
# The No of Images of Class : omelette in Dataset are : 1000
# The No of Images of Class : chicken_curry in Dataset are : 1000
# The No of Images of Class : pad_thai in Dataset are : 1000
# The No of Images of Class : hamburger in Dataset are : 1000
# The No of Images of Class : tacos in Dataset are : 1000
# The No of Images of Class : dumplings in Dataset are : 1000
# The No of Images of Class : red_velvet_cake in Dataset are : 1000
# The No of Images of Class : grilled_salmon in Dataset are : 1000
# The No of Images of Class : caprese_salad in Dataset are : 1000
# The No of Images of Class : tuna_tartare in Dataset are : 1000
# The No of Images of Class : lobster_roll_sandwich in Dataset are : 1000
# The No of Images of Class : hot_dog in Dataset are : 1000
# The No of Images of Class : fried_calamari in Dataset are : 1000
# The No of Images of Class : pho in Dataset are : 1000
# The No of Images of Class : breakfast_burrito in Dataset are : 1000
# The No of Images of Class : bread_pudding in Dataset are : 1000
# The No of Images of Class : foie_gras in Dataset are : 1000
# The No of Images of Class : beignets in Dataset are : 1000
# The No of Images of Class : carrot_cake in Dataset are : 1000
# The No of Images of Class : baklava in Dataset are : 1000
# The No of Images of Class : waffles in Dataset are : 1000
# The No of Images of Class : grilled_cheese_sandwich in Dataset are : 1000
# The No of Images of Class : crab_cakes in Dataset are : 1000
# The No of Images of Class : macarons in Dataset are : 1000
# The No of Images of Class : takoyaki in Dataset are : 1000
# The No of Images of Class : bibimbap in Dataset are : 1000
# The No of Images of Class : greek_salad in Dataset are : 1000
# The No of Images of Class : ice_cream in Dataset are : 1000
# The No of Images of Class : shrimp_and_grits in Dataset are : 1000
# The No of Images of Class : ramen in Dataset are : 1000
# The No of Images of Class : scallops in Dataset are : 1000
# The No of Images of Class : fish_and_chips in Dataset are : 1000
# The No of Images of Class : deviled_eggs in Dataset are : 1000
# The No of Images of Class : strawberry_shortcake in Dataset are : 1000
# The No of Images of Class : french_onion_soup in Dataset are : 1000
# The No of Images of Class : onion_rings in Dataset are : 1000
# The No of Images of Class : eggs_benedict in Dataset are : 1000
# The No of Images of Class : beef_tartare in Dataset are : 1000
# The No of Images of Class : tiramisu in Dataset are : 1000
# The No of Images of Class : huevos_rancheros in Dataset are : 1000
# The No of Images of Class : filet_mignon in Dataset are : 1000
# The No of Images of Class : beef_carpaccio in Dataset are : 1000
# The No of Images of Class : beet_salad in Dataset are : 1000
# The No of Images of Class : cannoli in Dataset are : 1000
# The No of Images of Class : prime_rib in Dataset are : 1000
# The No of Images of Class : chocolate_cake in Dataset are : 1000
# The No of Images of Class : croque_madame in Dataset are : 1000
# The No of Images of Class : guacamole in Dataset are : 1000
# The No of Images of Class : sushi in Dataset are : 1000
# The No of Images of Class : creme_brulee in Dataset are : 1000
# The No of Images of Class : steak in Dataset are : 1000
# The No of Images of Class : pulled_pork_sandwich in Dataset are : 1000
# The No of Images of Class : garlic_bread in Dataset are : 1000
# The No of Images of Class : spaghetti_carbonara in Dataset are : 1000
# The No of Images of Class : churros in Dataset are : 1000
# The No of Images of Class : clam_chowder in Dataset are : 1000
# The No of Images of Class : pancakes in Dataset are : 1000
# The No of Images of Class : lasagna in Dataset are : 1000
# The No of Images of Class : nachos in Dataset are : 1000
# The No of Images of Class : french_fries in Dataset are : 1000
# The No of Images of Class : hummus in Dataset are : 1000

# %% [markdown]
# #####Dataset Information
#
# This Dataset has 101 Classes with 1000 images for each class

# %% [markdown]
# # Splitting the Data into Training and Testing Data
#
# There are two files in meta folder train.txt and test.txt in which list of images is given which needed to be in training set and testing set
#
# * Training Set includes 750 images for each class
# * Testing Set incldes 250 images for each class

# %%
def prepare_data(filepath , src_file  , dest_file):
  classes_images = dict()
  for folder_name in os.listdir(src_file):
    classes_images[folder_name] = []
    

  with open(filepath , 'r') as txt:
    #Getting the paths for images
    paths = [read.strip() for read in txt.readlines()]

  for p in paths:
    food = p.split("/")
    classes_images[food[0]].append(food[1] + '.jpg')


  os.makedirs(dest_file , exist_ok = True)
  
  for food in classes_images.keys():
    print("\nCopying Images into " , food)

    if not os.path.exists(os.path.join("food" , food)):
      os.makedirs(os.path.join(dest_file , food))

    for i in classes_images[food]:
  
      copy(os.path.join(src_file , food , i) , os.path.join( dest_file, food , i))
      
    print(f"Copied {len(classes_images[food])} images into {food}")

# %%
# Testing Data
prepare_data("/content/food-101/meta/test.txt" ,"/content/food-101/images" , "food/test")
# Out:
# Copying Images into  frozen_yogurt
# Copied 250 images into frozen_yogurt
#
# Copying Images into  cheesecake
# Copied 250 images into cheesecake
#
# Copying Images into  risotto
# Copied 250 images into risotto
#
# Copying Images into  donuts
# Copied 250 images into donuts
#
# Copying Images into  sashimi
# Copied 250 images into sashimi
#
# Copying Images into  spring_rolls
# Copied 250 images into spring_rolls
#
# Copying Images into  panna_cotta
# Copied 250 images into panna_cotta
#
# Copying Images into  ravioli
# Copied 250 images into ravioli
#
# Copying Images into  apple_pie
# Copied 250 images into apple_pie
#
# Copying Images into  pork_chop
# Copied 250 images into pork_chop
#
# Copying Images into  club_sandwich
# Copied 250 images into club_sandwich
#
# Copying Images into  peking_duck
# Copied 250 images into peking_duck
#
# Copying Images into  gnocchi
# Copied 250 images into gnocchi
#
# Copying Images into  fried_rice
# Copied 250 images into fried_rice
#
# Copying Images into  chicken_wings
# Copied 250 images into chicken_wings
#
# Copying Images into  hot_and_sour_soup
# Copied 250 images into hot_and_sour_soup
#
# Copying Images into  edamame
# Copied 250 images into edamame
#
# Copying Images into  samosa
# Copied 250 images into samosa
#
# Copying Images into  ceviche
# Copied 250 images into ceviche
#
# Copying Images into  miso_soup
# Copied 250 images into miso_soup
#
# Copying Images into  cheese_plate
# Copied 250 images into cheese_plate
#
# Copying Images into  caesar_salad
# Copied 250 images into caesar_salad
#
# Copying Images into  cup_cakes
# Copied 250 images into cup_cakes
#
# Copying Images into  baby_back_ribs
# Copied 250 images into baby_back_ribs
#
# Copying Images into  mussels
# Copied 250 images into mussels
#
# Copying Images into  bruschetta
# Copied 250 images into bruschetta
#
# Copying Images into  chicken_quesadilla
# Copied 250 images into chicken_quesadilla
#
# Copying Images into  falafel
# Copied 250 images into falafel
#
# Copying Images into  macaroni_and_cheese
# Copied 250 images into macaroni_and_cheese
#
# Copying Images into  poutine
# Copied 250 images into poutine
#
# Copying Images into  spaghetti_bolognese
# Copied 250 images into spaghetti_bolognese
#
# Copying Images into  gyoza
# Copied 250 images into gyoza
#
# Copying Images into  paella
# Copied 250 images into paella
#
# Copying Images into  oysters
# Copied 250 images into oysters
#
# Copying Images into  pizza
# Copied 250 images into pizza
#
# Copying Images into  french_toast
# Copied 250 images into french_toast
#
# Copying Images into  chocolate_mousse
# Copied 250 images into chocolate_mousse
#
# Copying Images into  lobster_bisque
# Copied 250 images into lobster_bisque
#
# Copying Images into  escargots
# Copied 250 images into escargots
#
# Copying Images into  seaweed_salad
# Copied 250 images into seaweed_salad
#
# Copying Images into  omelette
# Copied 250 images into omelette
#
# Copying Images into  chicken_curry
# Copied 250 images into chicken_curry
#
# Copying Images into  pad_thai
# Copied 250 images into pad_thai
#
# Copying Images into  hamburger
# Copied 250 images into hamburger
#
# Copying Images into  tacos
# Copied 250 images into tacos
#
# Copying Images into  dumplings
# Copied 250 images into dumplings
#
# Copying Images into  red_velvet_cake
# Copied 250 images into red_velvet_cake
#
# Copying Images into  grilled_salmon
# Copied 250 images into grilled_salmon
#
# Copying Images into  caprese_salad
# Copied 250 images into caprese_salad
#
# Copying Images into  tuna_tartare
# Copied 250 images into tuna_tartare
#
# Copying Images into  lobster_roll_sandwich
# Copied 250 images into lobster_roll_sandwich
#
# Copying Images into  hot_dog
# Copied 250 images into hot_dog
#
# Copying Images into  fried_calamari
# Copied 250 images into fried_calamari
#
# Copying Images into  pho
# Copied 250 images into pho
#
# Copying Images into  breakfast_burrito
# Copied 250 images into breakfast_burrito
#
# Copying Images into  bread_pudding
# Copied 250 images into bread_pudding
#
# Copying Images into  foie_gras
# Copied 250 images into foie_gras
#
# Copying Images into  beignets
# Copied 250 images into beignets
#
# Copying Images into  carrot_cake
# Copied 250 images into carrot_cake
#
# Copying Images into  baklava
# Copied 250 images into baklava
#
# Copying Images into  waffles
# Copied 250 images into waffles
#
# Copying Images into  grilled_cheese_sandwich
# Copied 250 images into grilled_cheese_sandwich
#
# Copying Images into  crab_cakes
# Copied 250 images into crab_cakes
#
# Copying Images into  macarons
# Copied 250 images into macarons
#
# Copying Images into  takoyaki
# Copied 250 images into takoyaki
#
# Copying Images into  bibimbap
# Copied 250 images into bibimbap
#
# Copying Images into  greek_salad
# Copied 250 images into greek_salad
#
# Copying Images into  ice_cream
# Copied 250 images into ice_cream
#
# Copying Images into  shrimp_and_grits
# Copied 250 images into shrimp_and_grits
#
# Copying Images into  ramen
# Copied 250 images into ramen
#
# Copying Images into  scallops
# Copied 250 images into scallops
#
# Copying Images into  fish_and_chips
# Copied 250 images into fish_and_chips
#
# Copying Images into  deviled_eggs
# Copied 250 images into deviled_eggs
#
# Copying Images into  strawberry_shortcake
# Copied 250 images into strawberry_shortcake
#
# Copying Images into  french_onion_soup
# Copied 250 images into french_onion_soup
#
# Copying Images into  onion_rings
# Copied 250 images into onion_rings
#
# Copying Images into  eggs_benedict
# Copied 250 images into eggs_benedict
#
# Copying Images into  beef_tartare
# Copied 250 images into beef_tartare
#
# Copying Images into  tiramisu
# Copied 250 images into tiramisu
#
# Copying Images into  huevos_rancheros
# Copied 250 images into huevos_rancheros
#
# Copying Images into  filet_mignon
# Copied 250 images into filet_mignon
#
# Copying Images into  beef_carpaccio
# Copied 250 images into beef_carpaccio
#
# Copying Images into  beet_salad
# Copied 250 images into beet_salad
#
# Copying Images into  cannoli
# Copied 250 images into cannoli
#
# Copying Images into  prime_rib
# Copied 250 images into prime_rib
#
# Copying Images into  chocolate_cake
# Copied 250 images into chocolate_cake
#
# Copying Images into  croque_madame
# Copied 250 images into croque_madame
#
# Copying Images into  guacamole
# Copied 250 images into guacamole
#
# Copying Images into  sushi
# Copied 250 images into sushi
#
# Copying Images into  creme_brulee
# Copied 250 images into creme_brulee
#
# Copying Images into  steak
# Copied 250 images into steak
#
# Copying Images into  pulled_pork_sandwich
# Copied 250 images into pulled_pork_sandwich
#
# Copying Images into  garlic_bread
# Copied 250 images into garlic_bread
#
# Copying Images into  spaghetti_carbonara
# Copied 250 images into spaghetti_carbonara
#
# Copying Images into  churros
# Copied 250 images into churros
#
# Copying Images into  clam_chowder
# Copied 250 images into clam_chowder
#
# Copying Images into  pancakes
# Copied 250 images into pancakes
#
# Copying Images into  lasagna
# Copied 250 images into lasagna
#
# Copying Images into  nachos
# Copied 250 images into nachos
#
# Copying Images into  french_fries
# Copied 250 images into french_fries
#
# Copying Images into  hummus
# Copied 250 images into hummus

# %%
# Training Data
prepare_data("/content/food-101/meta/train.txt" , "/content/food-101/images" , "food/train")
# Out:
# Copying Images into  frozen_yogurt
# Copied 750 images into frozen_yogurt
#
# Copying Images into  cheesecake
# Copied 750 images into cheesecake
#
# Copying Images into  risotto
# Copied 750 images into risotto
#
# Copying Images into  donuts
# Copied 750 images into donuts
#
# Copying Images into  sashimi
# Copied 750 images into sashimi
#
# Copying Images into  spring_rolls
# Copied 750 images into spring_rolls
#
# Copying Images into  panna_cotta
# Copied 750 images into panna_cotta
#
# Copying Images into  ravioli
# Copied 750 images into ravioli
#
# Copying Images into  apple_pie
# Copied 750 images into apple_pie
#
# Copying Images into  pork_chop
# Copied 750 images into pork_chop
#
# Copying Images into  club_sandwich
# Copied 750 images into club_sandwich
#
# Copying Images into  peking_duck
# Copied 750 images into peking_duck
#
# Copying Images into  gnocchi
# Copied 750 images into gnocchi
#
# Copying Images into  fried_rice
# Copied 750 images into fried_rice
#
# Copying Images into  chicken_wings
# Copied 750 images into chicken_wings
#
# Copying Images into  hot_and_sour_soup
# Copied 750 images into hot_and_sour_soup
#
# Copying Images into  edamame
# Copied 750 images into edamame
#
# Copying Images into  samosa
# Copied 750 images into samosa
#
# Copying Images into  ceviche
# Copied 750 images into ceviche
#
# Copying Images into  miso_soup
# Copied 750 images into miso_soup
#
# Copying Images into  cheese_plate
# Copied 750 images into cheese_plate
#
# Copying Images into  caesar_salad
# Copied 750 images into caesar_salad
#
# Copying Images into  cup_cakes
# Copied 750 images into cup_cakes
#
# Copying Images into  baby_back_ribs
# Copied 750 images into baby_back_ribs
#
# Copying Images into  mussels
# Copied 750 images into mussels
#
# Copying Images into  bruschetta
# Copied 750 images into bruschetta
#
# Copying Images into  chicken_quesadilla
# Copied 750 images into chicken_quesadilla
#
# Copying Images into  falafel
# Copied 750 images into falafel
#
# Copying Images into  macaroni_and_cheese
# Copied 750 images into macaroni_and_cheese
#
# Copying Images into  poutine
# Copied 750 images into poutine
#
# Copying Images into  spaghetti_bolognese
# Copied 750 images into spaghetti_bolognese
#
# Copying Images into  gyoza
# Copied 750 images into gyoza
#
# Copying Images into  paella
# Copied 750 images into paella
#
# Copying Images into  oysters
# Copied 750 images into oysters
#
# Copying Images into  pizza
# Copied 750 images into pizza
#
# Copying Images into  french_toast
# Copied 750 images into french_toast
#
# Copying Images into  chocolate_mousse
# Copied 750 images into chocolate_mousse
#
# Copying Images into  lobster_bisque
# Copied 750 images into lobster_bisque
#
# Copying Images into  escargots
# Copied 750 images into escargots
#
# Copying Images into  seaweed_salad
# Copied 750 images into seaweed_salad
#
# Copying Images into  omelette
# Copied 750 images into omelette
#
# Copying Images into  chicken_curry
# Copied 750 images into chicken_curry
#
# Copying Images into  pad_thai
# Copied 750 images into pad_thai
#
# Copying Images into  hamburger
# Copied 750 images into hamburger
#
# Copying Images into  tacos
# Copied 750 images into tacos
#
# Copying Images into  dumplings
# Copied 750 images into dumplings
#
# Copying Images into  red_velvet_cake
# Copied 750 images into red_velvet_cake
#
# Copying Images into  grilled_salmon
# Copied 750 images into grilled_salmon
#
# Copying Images into  caprese_salad
# Copied 750 images into caprese_salad
#
# Copying Images into  tuna_tartare
# Copied 750 images into tuna_tartare
#
# Copying Images into  lobster_roll_sandwich
# Copied 750 images into lobster_roll_sandwich
#
# Copying Images into  hot_dog
# Copied 750 images into hot_dog
#
# Copying Images into  fried_calamari
# Copied 750 images into fried_calamari
#
# Copying Images into  pho
# Copied 750 images into pho
#
# Copying Images into  breakfast_burrito
# Copied 750 images into breakfast_burrito
#
# Copying Images into  bread_pudding
# Copied 750 images into bread_pudding
#
# Copying Images into  foie_gras
# Copied 750 images into foie_gras
#
# Copying Images into  beignets
# Copied 750 images into beignets
#
# Copying Images into  carrot_cake
# Copied 750 images into carrot_cake
#
# Copying Images into  baklava
# Copied 750 images into baklava
#
# Copying Images into  waffles
# Copied 750 images into waffles
#
# Copying Images into  grilled_cheese_sandwich
# Copied 750 images into grilled_cheese_sandwich
#
# Copying Images into  crab_cakes
# Copied 750 images into crab_cakes
#
# Copying Images into  macarons
# Copied 750 images into macarons
#
# Copying Images into  takoyaki
# Copied 750 images into takoyaki
#
# Copying Images into  bibimbap
# Copied 750 images into bibimbap
#
# Copying Images into  greek_salad
# Copied 750 images into greek_salad
#
# Copying Images into  ice_cream
# Copied 750 images into ice_cream
#
# Copying Images into  shrimp_and_grits
# Copied 750 images into shrimp_and_grits
#
# Copying Images into  ramen
# Copied 750 images into ramen
#
# Copying Images into  scallops
# Copied 750 images into scallops
#
# Copying Images into  fish_and_chips
# Copied 750 images into fish_and_chips
#
# Copying Images into  deviled_eggs
# Copied 750 images into deviled_eggs
#
# Copying Images into  strawberry_shortcake
# Copied 750 images into strawberry_shortcake
#
# Copying Images into  french_onion_soup
# Copied 750 images into french_onion_soup
#
# Copying Images into  onion_rings
# Copied 750 images into onion_rings
#
# Copying Images into  eggs_benedict
# Copied 750 images into eggs_benedict
#
# Copying Images into  beef_tartare
# Copied 750 images into beef_tartare
#
# Copying Images into  tiramisu
# Copied 750 images into tiramisu
#
# Copying Images into  huevos_rancheros
# Copied 750 images into huevos_rancheros
#
# Copying Images into  filet_mignon
# Copied 750 images into filet_mignon
#
# Copying Images into  beef_carpaccio
# Copied 750 images into beef_carpaccio
#
# Copying Images into  beet_salad
# Copied 750 images into beet_salad
#
# Copying Images into  cannoli
# Copied 750 images into cannoli
#
# Copying Images into  prime_rib
# Copied 750 images into prime_rib
#
# Copying Images into  chocolate_cake
# Copied 750 images into chocolate_cake
#
# Copying Images into  croque_madame
# Copied 750 images into croque_madame
#
# Copying Images into  guacamole
# Copied 750 images into guacamole
#
# Copying Images into  sushi
# Copied 750 images into sushi
#
# Copying Images into  creme_brulee
# Copied 750 images into creme_brulee
#
# Copying Images into  steak
# Copied 750 images into steak
#
# Copying Images into  pulled_pork_sandwich
# Copied 750 images into pulled_pork_sandwich
#
# Copying Images into  garlic_bread
# Copied 750 images into garlic_bread
#
# Copying Images into  spaghetti_carbonara
# Copied 750 images into spaghetti_carbonara
#
# Copying Images into  churros
# Copied 750 images into churros
#
# Copying Images into  clam_chowder
# Copied 750 images into clam_chowder
#
# Copying Images into  pancakes
# Copied 750 images into pancakes
#
# Copying Images into  lasagna
# Copied 750 images into lasagna
#
# Copying Images into  nachos
# Copied 750 images into nachos
#
# Copying Images into  french_fries
# Copied 750 images into french_fries
#
# Copying Images into  hummus
# Copied 750 images into hummus

# %% [markdown]
# # Model Building

# %%
ckpt_path = os.path.join("/content/drive/MyDrive/Knowledge_distillation/Models/Student_mobileNetV2_model")
# os.makedirs(ckpt_path , exist_ok = True)
my_callbacks = [EarlyStopping(patience = 5) ,
                ModelCheckpoint(os.path.join(ckpt_path , "MobileNetScratch_{epoch:02d}.h5"))]

# %%
base_model = tf.keras.applications.mobilenet_v2.MobileNetV2(input_shape=(160, 160, 3), include_top=False, weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_160_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# 9420800/9406464 [==============================] - 0s 0us/step

# %%
x = tf.keras.layers.Reshape(target_shape=(16, 20, 100))(base_model.output)
x = tf.keras.layers.MaxPool2D(pool_size=(2,2))(x)
x = tf.keras.layers.Conv2D(28, (1, 3), padding='valid', use_bias=False)(x)
x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dropout(0.1)(x)
outputs = Dense(101 , activation = "softmax")(x)
model = tf.keras.models.Model(base_model.input , outputs)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 160, 160, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 80, 80, 32)   864         ['input_1[0][0]']
#
#  bn_Conv1 (BatchNormalization)  (None, 80, 80, 32)   128         ['Conv1[0][0]']
#
#  Conv1_relu (ReLU)              (None, 80, 80, 32)   0           ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (Depth  (None, 80, 80, 32)  288         ['Conv1_relu[0][0]']
#  wiseConv2D)
#
#  expanded_conv_depthwise_BN (Ba  (None, 80, 80, 32)  128         ['expanded_conv_depthwise[0][0]']
#  tchNormalization)
#
#  expanded_conv_depthwise_relu (  (None, 80, 80, 32)  0           ['expanded_conv_depthwise_BN[0][0
#  ReLU)                                                           ]']
#
#  expanded_conv_project (Conv2D)  (None, 80, 80, 16)  512         ['expanded_conv_depthwise_relu[0]
#                                                                  [0]']
#
#  expanded_conv_project_BN (Batc  (None, 80, 80, 16)  64          ['expanded_conv_project[0][0]']
#  hNormalization)
#
#  block_1_expand (Conv2D)        (None, 80, 80, 96)   1536        ['expanded_conv_project_BN[0][0]'
#                                                                  ]
#
#  block_1_expand_BN (BatchNormal  (None, 80, 80, 96)  384         ['block_1_expand[0][0]']
#  ization)
#
#  block_1_expand_relu (ReLU)     (None, 80, 80, 96)   0           ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D)    (None, 81, 81, 96)   0           ['block_1_expand_relu[0][0]']
#
#  block_1_depthwise (DepthwiseCo  (None, 40, 40, 96)  864         ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 40, 40, 96)  384         ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 40, 40, 96)   0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 40, 40, 24)   2304        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 40, 40, 24)  96          ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 40, 40, 144)  3456        ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNormal  (None, 40, 40, 144)  576        ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 40, 40, 144)  0           ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (DepthwiseCo  (None, 40, 40, 144)  1296       ['block_2_expand_relu[0][0]']
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 40, 40, 144)  576        ['block_2_depthwise[0][0]']
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 40, 40, 144)  0           ['block_2_depthwise_BN[0][0]']
#
#  block_2_project (Conv2D)       (None, 40, 40, 24)   3456        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 40, 40, 24)  96          ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 40, 40, 24)   0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 40, 40, 144)  3456        ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNormal  (None, 40, 40, 144)  576        ['block_3_expand[0][0]']
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 40, 40, 144)  0           ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D)    (None, 41, 41, 144)  0           ['block_3_expand_relu[0][0]']
#
#  block_3_depthwise (DepthwiseCo  (None, 20, 20, 144)  1296       ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 20, 20, 144)  576        ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 20, 20, 144)  0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 20, 20, 32)   4608        ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 20, 20, 32)  128         ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 20, 20, 192)  6144        ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 20, 20, 192)  768        ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 20, 20, 192)  0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 20, 20, 192)  1728       ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 20, 20, 192)  768        ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 20, 20, 192)  0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 20, 20, 32)   6144        ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 20, 20, 32)  128         ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 20, 20, 32)   0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 20, 20, 192)  6144        ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 20, 20, 192)  768        ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 20, 20, 192)  0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 20, 20, 192)  1728       ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 20, 20, 192)  768        ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 20, 20, 192)  0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 20, 20, 32)   6144        ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 20, 20, 32)  128         ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 20, 20, 32)   0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 20, 20, 192)  6144        ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 20, 20, 192)  768        ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 20, 20, 192)  0           ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D)    (None, 21, 21, 192)  0           ['block_6_expand_relu[0][0]']
#
#  block_6_depthwise (DepthwiseCo  (None, 10, 10, 192)  1728       ['block_6_pad[0][0]']
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 10, 10, 192)  768        ['block_6_depthwise[0][0]']
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 10, 10, 192)  0           ['block_6_depthwise_BN[0][0]']
#
#  block_6_project (Conv2D)       (None, 10, 10, 64)   12288       ['block_6_depthwise_relu[0][0]']
#
#  block_6_project_BN (BatchNorma  (None, 10, 10, 64)  256         ['block_6_project[0][0]']
#  lization)
#
#  block_7_expand (Conv2D)        (None, 10, 10, 384)  24576       ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNormal  (None, 10, 10, 384)  1536       ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 10, 10, 384)  0           ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (DepthwiseCo  (None, 10, 10, 384)  3456       ['block_7_expand_relu[0][0]']
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 10, 10, 384)  1536       ['block_7_depthwise[0][0]']
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 10, 10, 384)  0           ['block_7_depthwise_BN[0][0]']
#
#  block_7_project (Conv2D)       (None, 10, 10, 64)   24576       ['block_7_depthwise_relu[0][0]']
#
#  block_7_project_BN (BatchNorma  (None, 10, 10, 64)  256         ['block_7_project[0][0]']
#  lization)
#
#  block_7_add (Add)              (None, 10, 10, 64)   0           ['block_6_project_BN[0][0]',
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 10, 10, 384)  24576       ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNormal  (None, 10, 10, 384)  1536       ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 10, 10, 384)  0           ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (DepthwiseCo  (None, 10, 10, 384)  3456       ['block_8_expand_relu[0][0]']
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 10, 10, 384)  1536       ['block_8_depthwise[0][0]']
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 10, 10, 384)  0           ['block_8_depthwise_BN[0][0]']
#
#  block_8_project (Conv2D)       (None, 10, 10, 64)   24576       ['block_8_depthwise_relu[0][0]']
#
#  block_8_project_BN (BatchNorma  (None, 10, 10, 64)  256         ['block_8_project[0][0]']
#  lization)
#
#  block_8_add (Add)              (None, 10, 10, 64)   0           ['block_7_add[0][0]',
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 10, 10, 384)  24576       ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNormal  (None, 10, 10, 384)  1536       ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 10, 10, 384)  0           ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (DepthwiseCo  (None, 10, 10, 384)  3456       ['block_9_expand_relu[0][0]']
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 10, 10, 384)  1536       ['block_9_depthwise[0][0]']
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 10, 10, 384)  0           ['block_9_depthwise_BN[0][0]']
#
#  block_9_project (Conv2D)       (None, 10, 10, 64)   24576       ['block_9_depthwise_relu[0][0]']
#
#  block_9_project_BN (BatchNorma  (None, 10, 10, 64)  256         ['block_9_project[0][0]']
#  lization)
#
#  block_9_add (Add)              (None, 10, 10, 64)   0           ['block_8_add[0][0]',
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 10, 10, 384)  24576       ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchNorma  (None, 10, 10, 384)  1536       ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 10, 10, 384)  0           ['block_10_expand_BN[0][0]']
#
#  block_10_depthwise (DepthwiseC  (None, 10, 10, 384)  3456       ['block_10_expand_relu[0][0]']
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 10, 10, 384)  1536       ['block_10_depthwise[0][0]']
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 10, 10, 384)  0          ['block_10_depthwise_BN[0][0]']
#
#  block_10_project (Conv2D)      (None, 10, 10, 96)   36864       ['block_10_depthwise_relu[0][0]']
#
#  block_10_project_BN (BatchNorm  (None, 10, 10, 96)  384         ['block_10_project[0][0]']
#  alization)
#
#  block_11_expand (Conv2D)       (None, 10, 10, 576)  55296       ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchNorma  (None, 10, 10, 576)  2304       ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 10, 10, 576)  0           ['block_11_expand_BN[0][0]']
#
#  block_11_depthwise (DepthwiseC  (None, 10, 10, 576)  5184       ['block_11_expand_relu[0][0]']
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 10, 10, 576)  2304       ['block_11_depthwise[0][0]']
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 10, 10, 576)  0          ['block_11_depthwise_BN[0][0]']
#
#  block_11_project (Conv2D)      (None, 10, 10, 96)   55296       ['block_11_depthwise_relu[0][0]']
#
#  block_11_project_BN (BatchNorm  (None, 10, 10, 96)  384         ['block_11_project[0][0]']
#  alization)
#
#  block_11_add (Add)             (None, 10, 10, 96)   0           ['block_10_project_BN[0][0]',
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 10, 10, 576)  55296       ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchNorma  (None, 10, 10, 576)  2304       ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 10, 10, 576)  0           ['block_12_expand_BN[0][0]']
#
#  block_12_depthwise (DepthwiseC  (None, 10, 10, 576)  5184       ['block_12_expand_relu[0][0]']
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 10, 10, 576)  2304       ['block_12_depthwise[0][0]']
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 10, 10, 576)  0          ['block_12_depthwise_BN[0][0]']
#
#  block_12_project (Conv2D)      (None, 10, 10, 96)   55296       ['block_12_depthwise_relu[0][0]']
#
#  block_12_project_BN (BatchNorm  (None, 10, 10, 96)  384         ['block_12_project[0][0]']
#  alization)
#
#  block_12_add (Add)             (None, 10, 10, 96)   0           ['block_11_add[0][0]',
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 10, 10, 576)  55296       ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchNorma  (None, 10, 10, 576)  2304       ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 10, 10, 576)  0           ['block_13_expand_BN[0][0]']
#
#  block_13_pad (ZeroPadding2D)   (None, 11, 11, 576)  0           ['block_13_expand_relu[0][0]']
#
#  block_13_depthwise (DepthwiseC  (None, 5, 5, 576)   5184        ['block_13_pad[0][0]']
#  onv2D)
#
#  block_13_depthwise_BN (BatchNo  (None, 5, 5, 576)   2304        ['block_13_depthwise[0][0]']
#  rmalization)
#
#  block_13_depthwise_relu (ReLU)  (None, 5, 5, 576)   0           ['block_13_depthwise_BN[0][0]']
#
#  block_13_project (Conv2D)      (None, 5, 5, 160)    92160       ['block_13_depthwise_relu[0][0]']
#
#  block_13_project_BN (BatchNorm  (None, 5, 5, 160)   640         ['block_13_project[0][0]']
#  alization)
#
#  block_14_expand (Conv2D)       (None, 5, 5, 960)    153600      ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchNorma  (None, 5, 5, 960)   3840        ['block_14_expand[0][0]']
#  lization)
#
#  block_14_expand_relu (ReLU)    (None, 5, 5, 960)    0           ['block_14_expand_BN[0][0]']
#
#  block_14_depthwise (DepthwiseC  (None, 5, 5, 960)   8640        ['block_14_expand_relu[0][0]']
#  onv2D)
#
#  block_14_depthwise_BN (BatchNo  (None, 5, 5, 960)   3840        ['block_14_depthwise[0][0]']
#  rmalization)
#
#  block_14_depthwise_relu (ReLU)  (None, 5, 5, 960)   0           ['block_14_depthwise_BN[0][0]']
#
#  block_14_project (Conv2D)      (None, 5, 5, 160)    153600      ['block_14_depthwise_relu[0][0]']
#
#  block_14_project_BN (BatchNorm  (None, 5, 5, 160)   640         ['block_14_project[0][0]']
#  alization)
#
#  block_14_add (Add)             (None, 5, 5, 160)    0           ['block_13_project_BN[0][0]',
#                                                                   'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, 5, 5, 960)    153600      ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchNorma  (None, 5, 5, 960)   3840        ['block_15_expand[0][0]']
#  lization)
#
#  block_15_expand_relu (ReLU)    (None, 5, 5, 960)    0           ['block_15_expand_BN[0][0]']
#
#  block_15_depthwise (DepthwiseC  (None, 5, 5, 960)   8640        ['block_15_expand_relu[0][0]']
#  onv2D)
#
#  block_15_depthwise_BN (BatchNo  (None, 5, 5, 960)   3840        ['block_15_depthwise[0][0]']
#  rmalization)
#
#  block_15_depthwise_relu (ReLU)  (None, 5, 5, 960)   0           ['block_15_depthwise_BN[0][0]']
#
#  block_15_project (Conv2D)      (None, 5, 5, 160)    153600      ['block_15_depthwise_relu[0][0]']
#
#  block_15_project_BN (BatchNorm  (None, 5, 5, 160)   640         ['block_15_project[0][0]']
#  alization)
#
#  block_15_add (Add)             (None, 5, 5, 160)    0           ['block_14_add[0][0]',
#                                                                   'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, 5, 5, 960)    153600      ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchNorma  (None, 5, 5, 960)   3840        ['block_16_expand[0][0]']
#  lization)
#
#  block_16_expand_relu (ReLU)    (None, 5, 5, 960)    0           ['block_16_expand_BN[0][0]']
#
#  block_16_depthwise (DepthwiseC  (None, 5, 5, 960)   8640        ['block_16_expand_relu[0][0]']
#  onv2D)
#
#  block_16_depthwise_BN (BatchNo  (None, 5, 5, 960)   3840        ['block_16_depthwise[0][0]']
#  rmalization)
#
#  block_16_depthwise_relu (ReLU)  (None, 5, 5, 960)   0           ['block_16_depthwise_BN[0][0]']
#
#  block_16_project (Conv2D)      (None, 5, 5, 320)    307200      ['block_16_depthwise_relu[0][0]']
#
#  block_16_project_BN (BatchNorm  (None, 5, 5, 320)   1280        ['block_16_project[0][0]']
#  alization)
#
#  Conv_1 (Conv2D)                (None, 5, 5, 1280)   409600      ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalization)  (None, 5, 5, 1280)  5120        ['Conv_1[0][0]']
#
#  out_relu (ReLU)                (None, 5, 5, 1280)   0           ['Conv_1_bn[0][0]']
#
#  reshape (Reshape)              (None, 16, 20, 100)  0           ['out_relu[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 8, 10, 100)   0           ['reshape[0][0]']
#
#  conv2d (Conv2D)                (None, 8, 8, 28)     8400        ['max_pooling2d[0][0]']
#
#  flatten (Flatten)              (None, 1792)         0           ['conv2d[0][0]']
#
#  dropout (Dropout)              (None, 1792)         0           ['flatten[0][0]']
#
#  dense (Dense)                  (None, 101)          181093      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 2,447,477
# Trainable params: 2,413,365
# Non-trainable params: 34,112
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
model.compile(optimizer = "adam" , metrics = ["accuracy"] , loss = "categorical_crossentropy")

# %% [markdown]
# ### Data Augementation

# %%
train_datagen = ImageDataGenerator(
                             rotation_range = 180,
                             shear_range = 0.2,
                             zoom_range = 0.2,
                             horizontal_flip = True ,
                             vertical_flip = True,
                             width_shift_range=0.2,
                             height_shift_range=0.2,
                             validation_split=0.2 ,
                             rescale = 1/255
                             
)
test_datagen = ImageDataGenerator(rescale = 1/255)

# %%
train_generator = train_datagen.flow_from_directory(
    "/content/food/train" , 
    target_size = (160 , 160),
    class_mode = "categorical" ,
    batch_size = 256

)
test_generator = test_datagen.flow_from_directory(
    "/content/food/test" , 
    target_size = (160 , 160),
    class_mode = "categorical",
    batch_size = 256,
)
# Out:
# Found 75750 images belonging to 101 classes.
# Found 25250 images belonging to 101 classes.

# %% [markdown]
# # Training

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer = opt, metrics = ["accuracy"] , loss = "categorical_crossentropy")

# %%
my_callbacks = [EarlyStopping(patience = 3) ,
                ModelCheckpoint(os.path.join(ckpt_path, "MobileNetScratch.{epoch:02d}.h5"), save_weights_only = True, save_best_only=False),
                tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss",factor=0.5, patience=2, verbose=1, min_delta=0.01)
                ]

# %%
history = model.fit(train_generator, 
                    epochs = 5, 
                    callbacks  = my_callbacks,
                    validation_data = test_generator)
# Out:
# Epoch 1/5
# 296/296 [==============================] - 837s 3s/step - loss: 1.7278 - accuracy: 0.5554 - val_loss: 1.8622 - val_accuracy: 0.5362 - lr: 1.0000e-04
# Epoch 2/5
# 296/296 [==============================] - 843s 3s/step - loss: 1.6174 - accuracy: 0.5821 - val_loss: 1.6949 - val_accuracy: 0.5701 - lr: 1.0000e-04
# Epoch 3/5
# 296/296 [==============================] - 843s 3s/step - loss: 1.5378 - accuracy: 0.5994 - val_loss: 1.5775 - val_accuracy: 0.5949 - lr: 1.0000e-04
# Epoch 4/5
# 296/296 [==============================] - 905s 3s/step - loss: 1.4678 - accuracy: 0.6158 - val_loss: 1.5755 - val_accuracy: 0.5970 - lr: 1.0000e-04
# Epoch 5/5
# 296/296 [==============================] - ETA: 0s - loss: 1.4043 - accuracy: 0.6295
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 296/296 [==============================] - 854s 3s/step - loss: 1.4043 - accuracy: 0.6295 - val_loss: 1.6273 - val_accuracy: 0.5844 - lr: 1.0000e-04
